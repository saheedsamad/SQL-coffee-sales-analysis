# %%
import pandas as pd
import numpy as np

# %%
Coffee= pd.read_csv('coffee.csv')
Coffee.head()
# Out:
#   transaction_id|transaction_date|transaction_time|transaction_qty|store_id|store_location|product_id|unit_price|product_category|product_type|product_detail
# 0  1|2023-01-01|07:06:11|2|5|Lower Manhattan|32|3...
# 1  2|2023-01-01|07:08:56|2|5|Lower Manhattan|57|3...
# 2  3|2023-01-01|07:14:04|2|5|Lower Manhattan|59|4...
# 3  4|2023-01-01|07:20:24|1|5|Lower Manhattan|22|2...
# 4  5|2023-01-01|07:22:41|2|5|Lower Manhattan|57|3...

# %%
import pandas as pd

# Load the dataset, treating the data as a single column
coffee = pd.read_csv('coffee.csv', header=None, delimiter=None)

# Split the single column into multiple columns using the delimiter '|'
coffee = coffee[0].str.split('|', expand=True)
# Assign proper column headers
coffee.columns = [
    "transaction_id", "transaction_date", "transaction_time", "transaction_qty",
    "store_id", "store_location", "product_id", "unit_price",
    "product_category", "product_type", "product_detail"
]

# Display the cleaned dataset
print("Cleaned Dataset:")
coffee
# Out:
# Cleaned Dataset:
#         transaction_id  transaction_date  transaction_time  transaction_qty  \
# 0       transaction_id  transaction_date  transaction_time  transaction_qty
# 1                    1        2023-01-01          07:06:11                2
# 2                    2        2023-01-01          07:08:56                2
# 3                    3        2023-01-01          07:14:04                2
# 4                    4        2023-01-01          07:20:24                1
# ...                ...               ...               ...              ...
# 149112          149452        2023-06-30          20:18:41                2
# 149113          149453        2023-06-30          20:25:10                2
# 149114          149454        2023-06-30          20:31:34                1
# 149115          149455        2023-06-30          20:57:19                1
# 149116          149456        2023-06-30          20:57:19                2
#
# ...

# %%
# Drop the first row, as it contains redundant header information
coffee = coffee.iloc[1:].reset_index(drop=True)

coffee
# Out:
#        transaction_id transaction_date transaction_time transaction_qty  \
# 0                   1       2023-01-01         07:06:11               2
# 1                   2       2023-01-01         07:08:56               2
# 2                   3       2023-01-01         07:14:04               2
# 3                   4       2023-01-01         07:20:24               1
# 4                   5       2023-01-01         07:22:41               2
# ...               ...              ...              ...             ...
# 149111         149452       2023-06-30         20:18:41               2
# 149112         149453       2023-06-30         20:25:10               2
# 149113         149454       2023-06-30         20:31:34               1
# 149114         149455       2023-06-30         20:57:19               1
# 149115         149456       2023-06-30         20:57:19               2
#
#        store_id   store_location product_id unit_price    product_category  \
# ...

# %%
# Check the data types of each column
print("Data Types of Each Column:")
print(coffee.dtypes)
# Out:
# Data Types of Each Column:
# transaction_id      object
# transaction_date    object
# transaction_time    object
# transaction_qty     object
# store_id            object
# store_location      object
# product_id          object
# unit_price          object
# product_category    object
# product_type        object
# product_detail      object
# dtype: object

# %%
# Convert columns to appropriate data types
coffee['transaction_id'] = pd.to_numeric(coffee['transaction_id'], errors='coerce')
coffee['transaction_date'] = pd.to_datetime(coffee['transaction_date'], errors='coerce')
coffee['transaction_time'] = pd.to_datetime(coffee['transaction_time'], format='%H:%M:%S', errors='coerce').dt.time
coffee['transaction_qty'] = pd.to_numeric(coffee['transaction_qty'], errors='coerce')
coffee['store_id'] = pd.to_numeric(coffee['store_id'], errors='coerce')
coffee['unit_price'] = pd.to_numeric(coffee['unit_price'], errors='coerce')

# Verify the changes
print("Updated Data Types:")
print(coffee.dtypes)
# Out:
# Updated Data Types:
# transaction_id               int64
# transaction_date    datetime64[ns]
# transaction_time            object
# transaction_qty              int64
# store_id                     int64
# store_location              object
# product_id                  object
# unit_price                 float64
# product_category            object
# product_type                object
# product_detail              object
# dtype: object

# %%
# Check for null values in each column
print("Null values in each column:")
print(coffee.isnull().sum())
# Out:
# Null values in each column:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# dtype: int64

# %%
coffee
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location product_id  unit_price    product_category  \
# ...

# %%
# Check for duplicate rows
duplicate_count = coffee.duplicated().sum()

# Print the number of duplicate rows
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
# Save the cleaned dataset to a CSV file
cleaned_file_name = 'cofeedata4.csv'
coffee.to_csv(cleaned_file_name, index=False)

print(f"The cleaned dataset has been saved as '{cleaned_file_name}'.")
# Out:
# The cleaned dataset has been saved as 'cofeedata4.csv'.
